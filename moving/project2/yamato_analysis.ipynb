# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
plt.style.use('ggplot')
import datetime as dt
import seaborn as sns

# %%
aku = pd.read_csv("csvfile/aku.csv")
ari = pd.read_csv("csvfile/ari.csv")
ato = pd.read_csv("csvfile/ato.csv")
heart = pd.read_csv("csvfile/heart.csv")
sakai = pd.read_csv("csvfile/sakai.csv")
yamato = pd.read_csv("csvfile/yamato.csv")

aku = aku.drop(["Unnamed: 0"], axis=1)
ari = ari.drop(["Unnamed: 0"], axis=1)
ato = ato.drop(["Unnamed: 0"], axis=1)
heart = heart.drop(["Unnamed: 0"], axis=1)
sakai = sakai.drop(["Unnamed: 0"], axis=1)
yamato = yamato.drop(["Unnamed: 0"], axis=1)

# %% [markdown]
# # ヤマト引越センター

# %%
t1 = []
t2 = []

# %%
for i in range(len(sakai)):
   if sakai["引越し先"][i] in ("青森", "岩手", "宮城", "秋田", "山形", "福島"):
      t1.append("東北")
   elif sakai["引越し先"][i] in ("茨城", "栃木", "群馬", "埼玉", "千県", "東京", "神奈川", "山梨", "長野"):
      t1.append("関東")
   elif sakai["引越し先"][i] in ("新潟", "富山", "石川",  "福井"):
      t1.append("北陸")
   elif sakai["引越し先"][i] in ("岐阜",  "静岡",  "愛知",  "三重"):
      t1.append("中部")
   elif sakai["引越し先"][i] in ("滋賀",  "京都",  "大阪",  "兵庫",  "奈良",  "和歌山"):
      t1.append("近畿")
   elif sakai["引越し先"][i] in ("鳥取",  "島根",  "岡山",  "広島",  "山口"):
      t1.append("中国")
   elif sakai["引越し先"][i] in ("徳島",  "香川",  "愛媛",  "高知"):
      t1.append("四国")
   elif sakai["引越し先"][i] in ("福岡",  "佐賀",  "長崎",  "熊本",  "大分",  "宮崎",  "鹿児島"):
      t1.append("九州")
   elif sakai["引越し先"][i] == "沖縄":
      t1.append("沖縄")
   else:
      t1.append("北海道")

# %%
for i in range(len(yamato)):
   if yamato["現在地"][i] in ("青森", "岩手", "宮城", "秋田", "山形", "福島"):
      t2.append("東北")
   elif yamato["現在地"][i] in ("茨城", "栃木", "群馬", "埼玉", "千県", "東京", "神奈川", "山梨", "長野"):
      t2.append("関東")
   elif yamato["現在地"][i] in ("新潟", "富山", "石川",  "福井"):
      t2.append("北陸")
   elif yamato["現在地"][i] in ("岐阜",  "静岡",  "愛知",  "三重"):
      t2.append("中部")
   elif yamato["現在地"][i] in ("滋賀",  "京都",  "大阪",  "兵庫",  "奈良",  "和歌山"):
      t2.append("近畿")
   elif yamato["現在地"][i] in ("鳥取",  "島根",  "岡山",  "広島",  "山口"):
      t2.append("中国")
   elif yamato["現在地"][i] in ("徳島",  "香川",  "愛媛",  "高知"):
      t2.append("四国")
   elif yamato["現在地"][i] in ("福岡",  "佐賀",  "長崎",  "熊本",  "大分",  "宮崎",  "鹿児島"):
      t2.append("九州")
   elif yamato["現在地"][i] == "沖縄":
      t2.append("沖縄")
   else:
      t2.append("北海道")

# %%
yamato["移住地方"] = t2
yamato["移住先地方"] = t1

# %%
yamato["引越し時期"] = pd.to_datetime(yamato["引越し時期"])
yamato_2022 = yamato[(yamato["引越し時期"] > dt.datetime(2022,1,1)) & (yamato["引越し時期"] < dt.datetime(2022,12,31))]
print(yamato_2022.shape)
# Out:
# (187, 17)

# %%
yamato_2022.groupby("移住地方").mean()
# Out:
# /var/folders/84/r3ff3p5977l5y2fvhc9v0xxh0000gn/T/ipykernel_30435/1931020597.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   yamato_2022.groupby("移住地方").mean()
#             評価  電話・メール対応    見積もり対応       作業員      サービス       家具量       家電量  \
# 移住地方
# 中国    4.428571  4.285714  4.428571  4.428571  4.571429  4.714286  5.714286
# 中部    4.359375  4.437500  4.500000  4.187500  4.312500  4.375000  4.000000
# 九州    4.437500  4.500000  4.500000  4.500000  4.250000  3.500000  3.500000
# 北海道   4.597826  4.478261  4.434783  4.826087  4.652174  6.043478  4.869565
# 北陸    4.750000  4.666667  5.000000  4.666667  4.666667  4.000000  1.666667
# 四国    4.500000  4.500000  4.750000  3.750000  5.000000  5.250000  6.000000
# 東北    4.295455  4.136364  4.272727  4.272727  4.500000  5.318182  4.545455
# ...

# %%
yamato_2022.groupby("移住先地方").mean()
# Out:
# /var/folders/84/r3ff3p5977l5y2fvhc9v0xxh0000gn/T/ipykernel_30435/2676019735.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   yamato_2022.groupby("移住先地方").mean()
#              評価  電話・メール対応    見積もり対応       作業員      サービス       家具量       家電量  \
# 移住先地方
# 中国     4.312500  4.333333  4.333333  4.333333  4.250000  4.750000  7.083333
# 中部     4.000000  4.214286  4.428571  3.714286  3.642857  3.928571  3.857143
# 九州     4.775000  4.800000  4.800000  4.800000  4.700000  4.000000  3.200000
# 北海道    4.583333  4.458333  4.625000  4.708333  4.541667  5.541667  3.666667
# 北陸     4.500000  4.500000  4.166667  4.666667  4.666667  4.166667  2.833333
# 四国     4.625000  4.500000  4.750000  4.250000  5.000000  5.000000  5.750000
# 東北     4.275000  4.100000  4.200000  4.250000  4.550000  6.150000  5.750000
# ...

# %%
sns.catplot(x="移住地方", data=yamato_2022, kind="count")

# %%
sns.catplot(x="移住先地方", data=yamato_2022, kind="count")

# %%
plt.hist(yamato_2022['見積もり比較社数'], bins=8)
# Out:
# (array([ 8.,  3., 17., 53., 58., 26.,  8., 14.]),
#  array([ 0.  ,  1.25,  2.5 ,  3.75,  5.  ,  6.25,  7.5 ,  8.75, 10.  ]),
#  <BarContainer object of 8 artists>)

# %% [markdown]
# 見積もり社数はbin=8にすると、若干正規分布に近づく

# %%
plt.hist(yamato_2022['評価'], bins=4)
# Out:
# (array([ 4., 17., 67., 99.]),
#  array([2.25  , 2.9375, 3.625 , 4.3125, 5.    ]),
#  <BarContainer object of 4 artists>)

# %%
#kind='boxen'と指定
sns.catplot(x='移住地方', y='見積もり比較社数', data=yamato_2022, kind='boxen')
plt.show()

# %%
sns.pairplot(data=yamato_2022, hue='評価')
plt.show()

# %%
sns.pairplot(data=yamato_2022, hue='移住地方')
plt.show()

# %%
yamato_score = pd.crosstab(yamato["引越し時期"],yamato["評価"], dropna=False)
yamato_score_month = yamato_score.resample("M").sum()
plt.figure()
yamato_score_month.plot(figsize=(18,8))
# Out:
# <AxesSubplot: xlabel='引越し時期'>

# %%
yamato_score = pd.crosstab(yamato["引越し時期"],yamato["電話・メール対応"], dropna=False)
yamato_score_month = yamato_score.resample("M").sum()
plt.figure()
yamato_score_month.plot(figsize=(18,8))
# Out:
# <AxesSubplot: xlabel='引越し時期'>

# %%
yamato_score = pd.crosstab(yamato["引越し時期"],yamato["見積もり対応"], dropna=False)
yamato_score_month = yamato_score.resample("M").sum()
plt.figure()
yamato_score_month.plot(figsize=(18,8))
# Out:
# <AxesSubplot: xlabel='引越し時期'>

# %%
yamato_score = pd.crosstab(yamato["引越し時期"],yamato["サービス"], dropna=False)
yamato_score_month = yamato_score.resample("M").sum()
plt.figure()
yamato_score_month.plot(figsize=(18,8))
# Out:
# <AxesSubplot: xlabel='引越し時期'>

# %%
# MeCabで形態素解析を行う
import MeCab

def mecab_text(text):
    
    #MeCabのインスタンスを作成（辞書はmecab-ipadic-neologdを使用）
    mecab = MeCab.Tagger('-Owakati')
    
    #形態素解析
    node = mecab.parseToNode(text)
    
    #形態素解析した結果を格納するリスト
    wordlist = []
    
    while node:
        #名詞のみリストに格納する
        if node.feature.split(',')[0] == '名詞':
            wordlist.append(node.surface)
        #形容詞を取得、elifで追加する
        elif node.feature.split(',')[0] == '形容詞':
            wordlist.append(node.surface)
        #動詞を取得、elifで追加する
        #elif node.feature.split(',')[0] == '動詞':
        #    wordlist.append(node.surface)
        node = node.next
    return wordlist

# 形態素結果をリスト化し、データフレームdf1に結果を列追加する
yamato_2022['words'] = yamato_2022['口コミ'].apply(mecab_text)
# Out:
# /var/folders/84/r3ff3p5977l5y2fvhc9v0xxh0000gn/T/ipykernel_30435/4195849273.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yamato_2022['words'] = yamato_2022['口コミ'].apply(mecab_text)

# %%
# nlplotで直近1カ月のレビューを可視化・分析
# 頻出単語
import nlplot

npt = nlplot.NLPlot(yamato_2022, target_col='words')

# top_nで頻出上位単語, min_freqで頻出下位単語を指定
stopwords = npt.get_stopword(top_n=0, min_freq=0)

npt.bar_ngram(
    title='uni-gram',
    xaxis_label='word_count',
    yaxis_label='word',
    ngram=1,
    top_n=50,
    stopwords=stopwords,
)
# Out:
# 100%|██████████| 187/187 [00:00<00:00, 89474.66it/s]

# %%
# ワードクラウド
npt.wordcloud(
    max_words=100,
    max_font_size=100,
    colormap='tab20_r',
    stopwords=stopwords,
)
